# %%
# # download CAT Bridge
! pip install catbridge
# Out:
# Collecting catbridge
#   Downloading catbridge-1.0-py3-none-any.whl.metadata (2.3 kB)
# Downloading catbridge-1.0-py3-none-any.whl (23 kB)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: catbridge
# Successfully installed catbridge-1.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from catbridge import catbridge as cat

# Ignore the specific RuntimeWarning
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %% [markdown]
# # Case study 1

# %% [markdown]
# ## With annotation

# %%
gene_file = 'data/count.tsv'
metabo_file = 'data/metabolite.tsv'
design_file = 'data/design.tsv'
annotation_file = 'data/annotation.tsv'

target = 'Capsaicin'

score = cat.compute_corr(gene_file, metabo_file, design_file, annotation_file, target, cluster_count=8, aggregation_func=cat.repeat_aggregation_mean)
score
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['condition'] = metadata['group']
# Fitting size factors...
# ... done in 0.01 seconds.
#
# Fitting dispersions...
# ... done in 55.12 seconds.
#
# Fitting dispersion trend curve...
# ... done in 8.98 seconds.
#
# Fitting MAP dispersions...
# ... done in 53.26 seconds.
#
# Fitting LFCs...
# ... done in 4.89 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# ... done in 4.93 seconds.
# Log2 fold change & Wald test p-value: condition day50 vs day30
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Name
# BC332_24630_mrna    43.066452        0.509979  0.473698  0.865486  0.386772
# BC332_28045_mrna  1023.989258       -0.097466  0.146648  0.000000  1.000000
# BC332_26522_mrna     5.989098        0.625344  0.771734  0.680732  0.496041
# BC332_20665_mrna    47.424850        0.383797  0.283214  1.002058  0.316316
# BC332_02545_mrna    56.897411       -0.389283  0.311855 -0.927620  0.353605
# ...                       ...             ...       ...       ...       ...
# BC332_01212_mrna   143.220108        0.217395  0.327310  0.358667  0.719844
# BC332_10877_mrna    11.691274       -1.932803  0.905190 -2.024772  0.042891
# BC332_24678_mrna  1103.026245        0.549680  0.279953  1.606273  0.108214
# BC332_12879_mrna   799.454407        0.094063  0.100309  0.000000  1.000000
# BC332_14739_mrna  2823.842773        0.202900  0.036425  2.824979  0.004728
#
#                       padj
# Name
# BC332_24630_mrna  0.613950
# BC332_28045_mrna  1.000000
# BC332_26522_mrna  0.728207
# BC332_20665_mrna  0.531229
# BC332_02545_mrna  0.575917
# ...                    ...
# BC332_01212_mrna  0.933983
# BC332_10877_mrna  0.111682
# BC332_24678_mrna  0.235758
# BC332_12879_mrna  1.000000
# BC332_14739_mrna  0.017519
#
# [22866 rows x 6 columns]
#                                               Name   Granger       CCM  \
# 0                                 BC332_24630_mrna  0.134216 -0.875822
# 1                                 BC332_28045_mrna  0.522355 -0.570297
# 2                                 BC332_26522_mrna  0.907257  0.366902
# 3                                 BC332_20665_mrna  0.439400  0.802072
# 4                                 BC332_18933_mrna  0.029154 -0.403972
# ...                                            ...       ...       ...
# 34972                             BC332_30878_mrna       NaN       NaN
# 34973                             BC332_29250_mrna       NaN       NaN
# 34974                     ## 32703 queries scanned       NaN       NaN
# 34975  ## Total time (seconds): 108.31248617172241       NaN       NaN
# 34976                          ## Rate: 301.93 q/s       NaN       NaN
#
#             CCA       DTW       CCF  Spearman   Pearson     baseMean  \
# 0      0.755946  3.559912 -0.484449 -0.750000 -0.755946    43.066452
# 1      0.876060  0.934319  0.278131  0.928571  0.876060  1023.989258
# 2      0.416522  2.854675 -0.601533 -0.214286 -0.416522     5.989098
# 3      0.721350  4.360383 -0.628142 -0.821429 -0.721350    47.424850
# 4      0.791587  5.249502 -0.244029 -0.750000 -0.791587          NaN
# ...         ...       ...       ...       ...       ...          ...
# 34972       NaN  3.791565       NaN       NaN       NaN          NaN
# 34973       NaN  3.791565       NaN       NaN       NaN          NaN
# 34974       NaN       NaN       NaN       NaN       NaN          NaN
# 34975       NaN       NaN       NaN       NaN       NaN          NaN
# 34976       NaN       NaN       NaN       NaN       NaN          NaN
#
#        log2FoldChange     lfcSE      stat    pvalue      padj  Cluster  \
# 0           -0.509979  0.473698  0.865486  0.386772  0.613950      3.0
# 1            0.097466  0.146648  0.000000  1.000000  1.000000      5.0
# 2           -0.625344  0.771734  0.680732  0.496041  0.728207      3.0
# 3           -0.383797  0.283214  1.002058  0.316316  0.531229      3.0
# 4                 NaN       NaN       NaN       NaN       NaN      1.0
# ...               ...       ...       ...       ...       ...      ...
# 34972             NaN       NaN       NaN       NaN       NaN      6.0
# 34973             NaN       NaN       NaN       NaN       NaN      6.0
# 34974             NaN       NaN       NaN       NaN       NaN      NaN
# 34975             NaN       NaN       NaN       NaN       NaN      NaN
# 34976             NaN       NaN       NaN       NaN       NaN      NaN
#
#                                              Description  Description_Score
# 0                                   Transcription factor                0.0
# 1                          Glycosyltransferase family 20                0.2
# 2                          LOB domain-containing protein                0.0
# 3                                                    NaN                0.1
# 4                  Protein of unknown function (DUF1218)                0.0
# ...                                                  ...                ...
# 34972                                              Cupin                0.0
# 34973  Belongs to the TRAFAC class dynamin-like GTPas...                0.2
# 34974                                                NaN                0.1
# 34975                                                NaN                0.1
# 34976                                                NaN                0.1
#
# [34977 rows x 17 columns]

# %%
result = cat.compute_score(score, "CCM")
result.to_csv('result.csv', index=False)
result.head(10)
# Out:
#                 Name       CCM  log2FoldChange  Cluster     Score
# 1   BC332_05016_mrna  0.550121       27.811433      7.0  1.000000
# 2   BC332_05249_mrna -0.074505       26.748905      2.0  0.843124
# 3   BC332_24622_mrna  0.998743        0.346102      7.0  0.840474
# 4   BC332_31360_mrna  0.996827        0.327020      3.0  0.839587
# 5   BC332_01046_mrna  0.998056        0.155833      7.0  0.838896
# 6   BC332_06737_mrna  0.995191        0.308329      7.0  0.838814
# 7   BC332_24224_mrna  0.996386        0.215871      7.0  0.838649
# 8   BC332_03087_mrna  0.994395        0.225526      7.0  0.837930
# 9   BC332_13934_mrna  0.990714        0.392121      7.0  0.837631
# 10  BC332_17770_mrna  0.994575        0.165498      7.0  0.837589

# %%
result
# Out:
#                                               Name       CCM  log2FoldChange  \
# 1                                 BC332_05016_mrna  0.550121       27.811433
# 2                                 BC332_05249_mrna -0.074505       26.748905
# 3                                 BC332_24622_mrna  0.998743        0.346102
# 4                                 BC332_31360_mrna  0.996827        0.327020
# 5                                 BC332_01046_mrna  0.998056        0.155833
# ...                                            ...       ...             ...
# 34973                             BC332_30878_mrna       NaN             NaN
# 34974                             BC332_29250_mrna       NaN             NaN
# 34975                     ## 32703 queries scanned       NaN             NaN
# 34976  ## Total time (seconds): 108.31248617172241       NaN             NaN
# 34977                          ## Rate: 301.93 q/s       NaN             NaN
#
#        Cluster     Score
# 1          7.0  1.000000
# 2          2.0  0.843124
# 3          7.0  0.840474
# 4          3.0  0.839587
# 5          7.0  0.838896
# ...        ...       ...
# 34973      6.0       NaN
# 34974      6.0       NaN
# 34975      NaN       NaN
# 34976      NaN       NaN
# 34977      NaN       NaN
#
# [34977 rows x 5 columns]

# %%
result[result['Name'] == "BC332_09814_mrna"]
# Out:
#                   Name       CCM  log2FoldChange  Cluster     Score
# 3019  BC332_09814_mrna  0.555167         7.19897      7.0  0.735318

# %%
cat.Yuanfang(result, target, annotation_file)
# Out:
# Please enter your OpenAI API Key: ········
#
# Based on the provided list of mRNA molecules, the one that may be involved in the synthesis of Capsaicin is BC332_05016_mrna, which is annotated as Acyl-transferase.
#
# Capsaicin is the compound responsible for the spicy taste and heat in chili peppers. It is synthesized through a series of enzymatic reactions in the plant's cells. Acyl-transferases are enzymes involved in the transfer of acyl groups from one molecule to another. In the case of Capsaicin synthesis, acyl-transferases are responsible for the transfer of acyl groups to vanillylamine, leading to the formation of Capsaicin.
#
# Therefore, BC332_05016_mrna (Acyl-transferase) is a potential candidate that may play a role in the synthesis of Capsaicin. However, further experimental studies would be required to confirm its exact involvement in Capsaicin biosynthesis.
#
#
# NOTICE: The output was produced by the large language model GPT 3.5 turbo, so it should only be regarded as a source of inspiration.

# %% [markdown]
# ## Without annotation

# %%
gene_file = 'data/gene.tsv'
metabo_file = 'data/metabolite.tsv'
design_file = 'data/design.tsv'
annotation_file = None

target = 'Capsaicin'

score = cat.compute_corr(gene_file, metabo_file, design_file, annotation_file, target, cluster_count=8, aggregation_func=cat.repeat_aggregation_mean)
result = cat.compute_score(score, "CCM")
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['condition'] = metadata['group']
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 25.67 seconds.
#
# Fitting dispersion trend curve...
# ... done in 5.18 seconds.
#
# Fitting MAP dispersions...
# ... done in 23.20 seconds.
#
# Fitting LFCs...
# ... done in 2.40 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition day50 vs day30
# ... done in 2.04 seconds.
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Name
# BC332_24630_mrna    43.066452        0.509979  0.473698  0.865486  0.386772
# BC332_28045_mrna  1023.989258       -0.097466  0.146648  0.000000  1.000000
# BC332_26522_mrna     5.989098        0.625344  0.771734  0.680732  0.496041
# BC332_20665_mrna    47.424850        0.383797  0.283214  1.002058  0.316316
# BC332_02545_mrna    56.897411       -0.389283  0.311855 -0.927620  0.353605
# ...                       ...             ...       ...       ...       ...
# BC332_01212_mrna   143.220108        0.217395  0.327310  0.358667  0.719844
# BC332_10877_mrna    11.691274       -1.932803  0.905190 -2.024772  0.042891
# BC332_24678_mrna  1103.026245        0.549680  0.279953  1.606273  0.108214
# BC332_12879_mrna   799.454407        0.094063  0.100309  0.000000  1.000000
# BC332_14739_mrna  2823.842773        0.202900  0.036425  2.824979  0.004728
#
#                       padj
# Name
# BC332_24630_mrna  0.613950
# BC332_28045_mrna  1.000000
# BC332_26522_mrna  0.728207
# BC332_20665_mrna  0.531229
# BC332_02545_mrna  0.575917
# ...                    ...
# BC332_01212_mrna  0.933983
# BC332_10877_mrna  0.111682
# BC332_24678_mrna  0.235758
# BC332_12879_mrna  1.000000
# BC332_14739_mrna  0.017519
#
# [22866 rows x 6 columns]

# %%
result.to_csv('result_wo_gene_annotation.csv', index=False)
result.head(10)
# Out:
#                 Name       CCM  log2FoldChange  Cluster     Score
# 1   BC332_05016_mrna  0.550121       27.811433        7  1.000000
# 2   BC332_05249_mrna -0.074505       26.748905        2  0.838658
# 3   BC332_24622_mrna  0.998743        0.346102        7  0.835926
# 4   BC332_21270_mrna  0.999043        0.325258        7  0.835900
# 5   BC332_07777_mrna  0.999330        0.261372        7  0.835563
# 6   BC332_05730_mrna  0.996692        0.387947        7  0.835391
# 7   BC332_21492_mrna  0.999124        0.248226        7  0.835386
# 8   BC332_09117_mrna  0.998797        0.218301        7  0.835041
# 9   BC332_31360_mrna  0.996827        0.327020        3  0.835012
# 10  BC332_20525_mrna  0.996493        0.336023        1  0.834940

# %%
gene = cat.read_upload(gene_file)
metabo = cat.read_upload(metabo_file)
design = cat.read_upload(design_file)

processed_gene = cat.repeat_aggregation_mean(gene, design)
processed_metabo = cat.repeat_aggregation_mean(metabo, design)
processed_gene.dropna(inplace=True)
processed_metabo.dropna(inplace=True)

t = cat.get_target(target, processed_metabo)
merged = cat.merge_and_reduce(gene, metabo, n_components=3)

scaled_gene = cat.scale_df(processed_gene)
scaled_metabo = cat.scale_df(processed_metabo)

# %%
cat.plot_result(result.head(10), 'Score', 'log2FoldChange', 'CCM')
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:1822: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['color'] = result[Granger_column].astype('category').cat.codes
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:1829: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result[log2FoldChange_column] = model.fit_transform(result[log2FoldChange_column].values.reshape(-1,1))
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:1830: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['size'] = np.abs(result[log2FoldChange_column]) * 150

# %%
cat.plot_line(processed_metabo, target)

# %%
cat.plot_pca(gene, design, 7)
cat.plot_pca(metabo, design, 7)
cat.plot_pca(merged, design, 7)

# %%
g_imp = cat.top_important_features(processed_gene, 15)
cat.plot_top_features(g_imp, color='flare')

m_imp = cat.top_important_features(processed_metabo, 15)
cat.plot_top_features(m_imp, color='crest')
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:1441: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(y_labels)
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:1441: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(y_labels)
# <module 'matplotlib.pyplot' from '/Applications/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
cat.plot_network(metabo, target, 20)
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 23004 (\N{CJK UNIFIED IDEOGRAPH-59DC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Applications/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 37210 (\N{CJK UNIFIED IDEOGRAPH-915A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
cat.plot_heatmap(scaled_metabo, palette='crest')
cat.plot_heatmap(scaled_gene, palette='flare')

# %%
fc = cat.compute_fc(gene_file, metabo_file, design_file=design_file, aggregation_func=cat.repeat_aggregation_mean, target=target)
cat.plot_volcano(fc, log2FoldChange_threshold=(2, -2), padj_threshold=0.05)
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/catbridge/catbridge.py:930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['condition'] = metadata['group']
# Fitting size factors...
# ... done in 0.00 seconds.
#
# Fitting dispersions...
# ... done in 23.45 seconds.
#
# Fitting dispersion trend curve...
# ... done in 5.18 seconds.
#
# Fitting MAP dispersions...
# ... done in 27.56 seconds.
#
# Fitting LFCs...
# ... done in 2.83 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition day50 vs day30
# ... done in 2.32 seconds.
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# Name
# BC332_24630_mrna    43.066452        0.509979  0.473698  0.865486  0.386772
# BC332_28045_mrna  1023.989258       -0.097466  0.146648  0.000000  1.000000
# BC332_26522_mrna     5.989098        0.625344  0.771734  0.680732  0.496041
# BC332_20665_mrna    47.424850        0.383797  0.283214  1.002058  0.316316
# BC332_02545_mrna    56.897411       -0.389283  0.311855 -0.927620  0.353605
# ...                       ...             ...       ...       ...       ...
# BC332_01212_mrna   143.220108        0.217395  0.327310  0.358667  0.719844
# BC332_10877_mrna    11.691274       -1.932803  0.905190 -2.024772  0.042891
# BC332_24678_mrna  1103.026245        0.549680  0.279953  1.606273  0.108214
# BC332_12879_mrna   799.454407        0.094063  0.100309  0.000000  1.000000
# BC332_14739_mrna  2823.842773        0.202900  0.036425  2.824979  0.004728
#
#                       padj
# Name
# BC332_24630_mrna  0.613950
# BC332_28045_mrna  1.000000
# BC332_26522_mrna  0.728207
# BC332_20665_mrna  0.531229
# BC332_02545_mrna  0.575917
# ...                    ...
# BC332_01212_mrna  0.933983
# BC332_10877_mrna  0.111682
# BC332_24678_mrna  0.235758
# BC332_12879_mrna  1.000000
# BC332_14739_mrna  0.017519
#
# [22866 rows x 6 columns]
